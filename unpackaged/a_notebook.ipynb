# %% [markdown]
# This is a Notebook

# %%
print("hello")
# Out:
# hello

# %%
from pptm.salut import say_hello_with_message

print(say_hello_with_message("wow"))
# Out:
# Hello, the message is: wow. The current time is: 2023-02-24 10-34-33-UTC.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [0, 1, 2, 3]
y = [3.1, 2.5, 4.0, 2.9]
plt.plot(x, y)
plt.ylim(bottom=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
